# %%
import glob
import os
from post_process import *

EXP_DATE = "2023-12-15"
EXP_DIR = glob.glob(f"../field_data/a2g/{EXP_DATE}*")
print(f"Processing date: {EXP_DATE}")

# %matplotlib inline
# Out:
# Processing date: 2023-12-15

# %%
processor = PostProcessor() 

FORCE = False
processed = processor.process_dates(EXP_DIR, FORCE)
# Out:
# Processing measurements: 100%|██████████| 10/10 [00:02<00:00,  4.60it/s, Status=Mesaurement ../field_data/measurements/2023-12-15_16_53 already processed. Loading from cache.]

# %%
processed["meas"][0]
# Out:
#       index        time  center_freq       dist     h_dist  v_dist wav_type  \
# 0         0        41.0         3564  33.330948  31.017933  12.200       ZC
# 1         0   41.400002         3564  33.326145  31.013559  12.198       ZC
# 2         0   41.799999         3564  33.324318  31.013559  12.193       ZC
# 3         0        43.0         3564  33.327656  31.017933  12.191       ZC
# 4         0   42.200001         3564  33.321026  31.013559  12.184       ZC
# ...     ...         ...          ...        ...        ...     ...      ...
# 1063      0  466.200012         3564  33.887798  31.606663  12.223       ZC
# 1064      0       467.0         3564  33.887798  31.606663  12.223       ZC
# 1065      0  466.600006         3564  33.887798  31.606663  12.223       ZC
# 1066      0  467.799988         3564  33.887798  31.606663  12.223       ZC
# 1067      0  467.399994         3564  33.887798  31.606663  12.223       ZC
#
# ...

# %%
processed["meas"][0].keys()
# Out:
# Index(['index', 'time', 'center_freq', 'dist', 'h_dist', 'v_dist', 'wav_type',
#        'detected', 'power', 'avgPower', 'snr', 'avgSnr', 'snr_2', 'avgSnr_2',
#        'freq_offset', 'path_loss', 'avg_pl', 'est_dist', 'peaks', 'orig_peaks',
#        'start_point', 'aod_theta', 'aod_phi', 'aoa_theta', 'aoa_phi', 'stage',
#        'corr', 'save_corr', 'rsrp', 'shadowing', 'multipath', 'delay',
#        'doppler', 'type', 'lat', 'lon', 'alt', 'pitch', 'yaw', 'roll', 'vel_x',
#        'vel_y', 'vel_z', 'heading', 'speed', 'cropped_sig', 'vehicle'],
#       dtype='object')

# %%
processed["config"][0].WAV_OPTS.SEQ_LEN
# Out:
# 401

# %%
processed["resultDir"][0]
# Out:
# '../field_data/post-results/2023-12-15_15_41/'

# %%
# Export all processed experiments to SigMF format.
# TX location defaults to LW1 / H_TOWER_LW1 from constants.py;
# pass tx_location=dict(...) to override.
write_sigmf_campaign(processed, out_base_dir='../field_data/sigMF/')
